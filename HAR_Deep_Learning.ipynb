# %% [markdown]
# <a href="https://colab.research.google.com/github/RISHAD-prog/Human_Activity_Recognition_UCF101/blob/main/HAR_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install remotezip tqdm opencv-python einops
# Install TensorFlow 2.10
# !pip install tensorflow==2.10.0
# Out:
# Requirement already satisfied: remotezip in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from remotezip) (2.31.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from remotezip) (0.9.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2023.7.22)
# Requirement already satisfied: tensorflow==2.10.0 in /usr/local/lib/python3.10/dist-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (3.9.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (23.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (0.33.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.41.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)

# %%
import tqdm
import random
import pathlib
import itertools
import collections

import cv2
import einops
import numpy as np
import remotezip as rz
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers

# %%
URL = 'https://storage.googleapis.com/thumos14_files/UCF101_videos.zip'

# %%
def list_files_per_class(zip_url):
  """
    List the files in each class of the dataset given the zip URL.

    Args:
      zip_url: URL from which the files can be unzipped.

    Return:
      files: List of files in each of the classes.
  """
  files = []
  with rz.RemoteZip(URL) as zip:
    for zip_info in zip.infolist():
      files.append(zip_info.filename)
  return files

# %%
def get_class(fname):
  """
    Retrieve the name of the class given a filename.

    Args:
      fname: Name of the file in the UCF101 dataset.

    Return:
      Class that the file belongs to.
  """
  return fname.split('_')[-3]

# %%
def download_from_zip(zip_url, to_dir, file_names):

  with rz.RemoteZip(zip_url) as zip:
    for fn in tqdm.tqdm(file_names):
      class_name = fn.split('_')[-3]
      zip.extract(fn, str(to_dir / class_name))
      unzipped_file = to_dir / class_name / fn

      fn = pathlib.Path(fn).parts[-1]
      output_file = to_dir / class_name / fn
      unzipped_file.rename(output_file)

# %%
def split_class_lists(files_for_class, count):

  split_files = []
  remainder = {}
  for cls in files_for_class:
    split_files.extend(files_for_class[cls][:count])
    remainder[cls] = files_for_class[cls][count:]
  return split_files, remainder

# %%
def get_files_per_class(files):
  """
    Retrieve the files that belong to each class.

    Args:
      files: List of files in the dataset.

    Return:
      Dictionary of class names (key) and files (values).
  """
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class

# %%
def download_ufc_101_subset(zip_url, num_classes, splits, download_dir):
  """
    Download a subset of the UFC101 dataset and split them into various parts, such as
    training, validation, and test.

    Args:
      zip_url: Zip URL containing data.
      num_classes: Number of labels.
      splits: Dictionary specifying the training, validation, test, etc. (key) division of data
              (value is number of files per split).
      download_dir: Directory to download data to.

    Return:
      dir: Posix path of the resulting directories containing the splits of data.
  """
  files = list_files_per_class(zip_url)
  for f in files:
    tokens = f.split('/')
    if len(tokens) <= 2:
      files.remove(f) # Remove that item from the list if it does not have a filename

  files_for_class = get_files_per_class(files)

  classes = list(files_for_class.keys())[:num_classes]

  for cls in classes:
    new_files_for_class = files_for_class[cls]
    random.shuffle(new_files_for_class)
    files_for_class[cls] = new_files_for_class

  # Only use the number of classes you want in the dictionary
  files_for_class = {x: files_for_class[x] for x in list(files_for_class)[:num_classes]}

  dirs = {}
  for split_name, split_count in splits.items():
    print(split_name, ":")
    split_dir = download_dir / split_name
    split_files, files_for_class = split_class_lists(files_for_class, split_count)
    download_from_zip(zip_url, split_dir, split_files)
    dirs[split_name] = split_dir

  return dirs

# %%
download_dir = pathlib.Path('./UCF101_subset/')
subset_paths = download_ufc_101_subset(URL,
                        num_classes = 10,
                        splits = {"train": 30, "val": 10, "test": 10},
                        download_dir = download_dir)
# Out:
# train :
# 100%|██████████| 300/300 [01:40<00:00,  2.97it/s]
# val :
# 100%|██████████| 100/100 [00:27<00:00,  3.60it/s]
# test :
# 100%|██████████| 100/100 [00:22<00:00,  4.39it/s]

# %%
download_dir = pathlib.Path('/content/UCF101_subset/')
video_count_train = len(list(download_dir.glob('train/*/*.avi')))
video_count_val = len(list(download_dir.glob('val/*/*.avi')))
video_count_test = len(list(download_dir.glob('test/*/*.avi')))
video_total = video_count_train + video_count_val + video_count_test
print(f"Total videos: {video_total}")
# Out:
# Total videos: 500

# %%
# !find /content/drive/MyDrive/Thesis/UCF101_subset
# Out:
# /content/drive/MyDrive/Thesis/UCF101_subset
# /content/drive/MyDrive/Thesis/UCF101_subset/train
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g25_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g16_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g21_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g15_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g09_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g23_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g23_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g14_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g01_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g03_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g14_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g13_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g05_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g01_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g17_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g04_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g11_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g02_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g07_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g16_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g19_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g11_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g24_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g12_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g12_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g07_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g18_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g04_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g10_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/v_ApplyEyeMakeup_g17_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyEyeMakeup/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g17_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g21_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g17_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g15_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g01_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g03_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g24_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g02_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g01_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g19_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g06_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g10_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g08_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g21_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g06_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g13_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g22_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g14_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g08_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g20_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g13_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g10_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g15_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g24_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g07_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g04_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g14_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g22_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g25_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/v_ApplyLipstick_g19_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/ApplyLipstick/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g01_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g11_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g16_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g19_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g04_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g20_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g12_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g10_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g16_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g14_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g17_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g03_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g06_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g02_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g09_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g11_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g23_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g05_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g08_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g12_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g02_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g18_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g02_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g04_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g23_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g10_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g20_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g25_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g22_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Archery/v_Archery_g24_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g22_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g09_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g23_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g03_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g22_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g17_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g12_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g16_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g05_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g06_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g15_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g09_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g01_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g24_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g11_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g01_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g06_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g16_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g12_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g24_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g12_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g05_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g14_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g15_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g25_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g25_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g08_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g02_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g19_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/v_BabyCrawling_g03_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BabyCrawling/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g05_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g13_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g10_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g06_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g14_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g12_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g12_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g06_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g22_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g11_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g23_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g18_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g02_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g24_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g06_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g17_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g05_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g19_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g19_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g18_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g01_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g02_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g17_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g25_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g08_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g08_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g01_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g15_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g16_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/v_BalanceBeam_g09_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BalanceBeam/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g07_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g14_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g10_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g23_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g03_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g15_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g13_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g01_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g24_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g24_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g20_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g22_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g06_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g03_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g22_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g08_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g12_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g20_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g04_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g13_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g07_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g01_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g05_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g09_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g07_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g15_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g08_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g20_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g03_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/v_BandMarching_g12_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BandMarching/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g08_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g25_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g09_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g13_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g14_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g23_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g15_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g25_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g18_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g08_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g09_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g01_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g04_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g09_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g23_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g11_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g17_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g06_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g22_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g10_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g03_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g04_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g02_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g16_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g03_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g17_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g03_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g21_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g05_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BaseballPitch/v_BaseballPitch_g11_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g23_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g06_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g22_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g20_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g14_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g02_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g04_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g25_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g07_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g21_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g14_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g12_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g09_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g23_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g07_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g07_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g09_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g03_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g01_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g01_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g11_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g15_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g14_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g17_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g17_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g10_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g25_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g08_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g08_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BasketballDunk/v_BasketballDunk_g12_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g21_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g25_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g15_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g14_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g08_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g09_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g12_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g19_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g18_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g20_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g19_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g07_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g20_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g23_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g01_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g16_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g13_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g21_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g17_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g15_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g03_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g10_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g01_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g12_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g03_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g22_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g04_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g08_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g02_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/train/Basketball/v_Basketball_g07_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g06_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g07_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g07_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g01_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g14_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g08_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g16_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g04_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g18_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g02_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g20_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g17_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g23_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g01_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g02_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g09_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g24_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g16_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g13_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g08_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g04_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g07_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g06_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g23_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g18_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g02_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g03_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g06_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g25_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/v_BenchPress_g13_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/train/BenchPress/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g23_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g21_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g05_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g03_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g25_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g08_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g16_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g06_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g19_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyEyeMakeup/v_ApplyEyeMakeup_g07_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g21_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g06_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g04_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g12_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g05_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g05_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g11_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g11_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g18_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/v_ApplyLipstick_g15_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/ApplyLipstick/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g18_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g24_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g02_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g03_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g01_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g15_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g06_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g08_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g13_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/v_Archery_g16_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Archery/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g20_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g23_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g10_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g07_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g17_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g13_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g04_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g09_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g18_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BabyCrawling/v_BabyCrawling_g08_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g16_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g22_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g03_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g21_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g10_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g06_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g15_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g03_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g04_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/v_BalanceBeam_g04_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BalanceBeam/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g15_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g02_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g03_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g01_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g19_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g09_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g23_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g16_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g19_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/v_BandMarching_g25_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BandMarching/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g21_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g23_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g19_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g24_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g01_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g16_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g04_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g02_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g24_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/v_BaseballPitch_g25_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BaseballPitch/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g15_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g24_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g24_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g20_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g19_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g15_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g12_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g13_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g10_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BasketballDunk/v_BasketballDunk_g01_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g12_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g06_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g03_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g19_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g15_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g22_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g02_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g11_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g05_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/val/Basketball/v_Basketball_g11_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g13_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g20_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g19_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g05_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g04_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g05_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g25_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g22_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g05_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/v_BenchPress_g09_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/val/BenchPress/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g02_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g09_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g25_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g20_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g24_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g10_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g25_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g18_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g01_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/v_ApplyEyeMakeup_g15_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyEyeMakeup/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g18_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g16_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g23_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g23_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g22_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g02_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g25_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g24_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g12_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/v_ApplyLipstick_g09_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/ApplyLipstick/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g10_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g11_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g23_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g21_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g20_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g17_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g13_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g09_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g24_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Archery/v_Archery_g21_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g22_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g17_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g02_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g07_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g13_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g16_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g18_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g02_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g19_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BabyCrawling/v_BabyCrawling_g13_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g20_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g17_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g13_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g14_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g09_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g23_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g21_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g21_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g20_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/v_BalanceBeam_g24_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BalanceBeam/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g02_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g23_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g12_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g05_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g16_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g18_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g15_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g09_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g18_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/v_BandMarching_g19_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BandMarching/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g07_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g23_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g20_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g13_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g08_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g12_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g17_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g19_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g14_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/v_BaseballPitch_g12_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BaseballPitch/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g18_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g06_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g03_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g20_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g05_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g22_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g03_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g02_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g18_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BasketballDunk/v_BasketballDunk_g17_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g19_c01.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g06_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g05_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g16_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g24_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g24_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g22_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g01_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g22_c07.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/UCF101
# /content/drive/MyDrive/Thesis/UCF101_subset/test/Basketball/v_Basketball_g10_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g08_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g14_c04.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g15_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g02_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g10_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g01_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g04_c03.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g06_c05.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g14_c06.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/v_BenchPress_g12_c02.avi
# /content/drive/MyDrive/Thesis/UCF101_subset/test/BenchPress/UCF101

# %%
def format_frame(frame, output_size):
 frame = tf.image.convert_image_dtype(frame, tf.float32)
 frame = tf.image.resize_with_pad(frame, *output_size)
 return frame

# %%
def frames_from_video_file(video_path, n_frames, output_size = (224,224), frame_step = 15):

  result = []
  src = cv2.VideoCapture(str(video_path))

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frame(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frame(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

# %%
def generate_frames(path, n_frames, training=False):
    class_names = sorted(set(p.name for p in path.iterdir() if p.is_dir()))
    class_ids_for_name = dict((name, idx) for idx, name in enumerate(class_names))

    def get_files_and_class_names():
        video_paths = list(path.glob('*/*.avi'))
        classes = [p.parent.name for p in video_paths]
        return video_paths, classes

    video_paths, classes = get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if training:
        random.shuffle(pairs)

    for path, name in pairs:
        video_frames = frames_from_video_file(path, n_frames)
        label = class_ids_for_name[name]  # Encode labels
        yield video_frames, label

# %%
import tensorflow as tf

# Define your data augmentation transformations using TensorFlow
def apply_data_augmentation(frames, label):
    # Create a tensor array to collect augmented frames
    augmented_frames = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)

    # Loop over frames and apply augmentation
    for frame in frames:
        augmented_frames = augmented_frames.write(augmented_frames.size(), apply_augmentation(frame))

    # Stack the augmented frames using tf.stack
    augmented_frames_tensor = augmented_frames.stack()

    # Manually calculate mean and std deviation for standardization
    mean, variance = tf.nn.moments(augmented_frames_tensor, axes=[0, 1, 2], keepdims=True)
    normalized_frames = (augmented_frames_tensor - mean) / tf.sqrt(variance + 1e-6)

    return normalized_frames, label

def apply_augmentation(frame):
    # Resize the frame
    resized_frame = tf.image.resize(frame, (224, 224))

    # Randomly flip horizontally
    horizontally_flipped_frame = tf.image.random_flip_left_right(resized_frame)

    # Adjust color using brightness, contrast, saturation, and hue adjustments
    adjusted_frame = tf.image.random_brightness(horizontally_flipped_frame, max_delta=0.2)
    adjusted_frame = tf.image.random_contrast(adjusted_frame, lower=0.8, upper=1.2)
    adjusted_frame = tf.image.random_saturation(adjusted_frame, lower=0.8, upper=1.2)
    adjusted_frame = tf.image.random_hue(adjusted_frame, max_delta=0.1)

    # Apply random rotation within [-10, 10] degrees
    rotation_angle = tf.random.uniform(shape=(), minval=-10, maxval=10)
    rotation_angle_radians = rotation_angle * (3.141592653589793 / 180.0)

    # Apply rotation using tf.image.rot90
    rotated_frame = tf.image.rot90(adjusted_frame, k=tf.cast(rotation_angle // 90, tf.int32))  # Rotate in 90-degree increments

    # Randomly flip vertically
    vertically_flipped_frame = tf.image.random_flip_up_down(rotated_frame)

    return vertically_flipped_frame

# Rest of your code...
# Same as before...

# %%
n_frames = 10
batch_size = 8
AUTOTUNE = tf.data.AUTOTUNE

output_signature = (tf.TensorSpec(shape=(None, None, None, 3), dtype=tf.float32),
                    tf.TensorSpec(shape=(), dtype=tf.int16))

# Training dataset
train_ds = tf.data.Dataset.from_generator(
    lambda: generate_frames(subset_paths['train'], n_frames, training=True),
    output_signature=output_signature)

train_ds = train_ds.map(apply_data_augmentation)
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
train_ds = train_ds.batch(batch_size)

# Validation dataset
val_ds = tf.data.Dataset.from_generator(
    lambda: generate_frames(subset_paths['val'], n_frames),
    output_signature=output_signature)

val_ds = val_ds.map(apply_data_augmentation)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)
val_ds = val_ds.batch(batch_size)

# Test dataset
test_ds = tf.data.Dataset.from_generator(
    lambda: generate_frames(subset_paths['test'], n_frames),
    output_signature=output_signature)

test_ds = test_ds.batch(batch_size)

# %%
train_frames, train_labels = next(iter(train_ds))
print(f'Shape of training set of frames: {train_frames.shape}')
print(f'Shape of training labels: {train_labels.shape}')

val_frames, val_labels = next(iter(val_ds))
print(f'Shape of validation set of frames: {val_frames.shape}')
print(f'Shape of validation labels: {val_labels.shape}')
# Out:
# Shape of training set of frames: (8, 10, 224, 224, 3)
# Shape of training labels: (8,)
# Shape of validation set of frames: (8, 10, 224, 224, 3)
# Shape of validation labels: (8,)

# %%
HEIGHT = 224
WIDTH = 224

# %%
from tensorflow.keras.layers import Conv2D, Conv3D, LayerNormalization, ReLU

def Conv2Plus1D(inputs, filters, kernel_size, padding):
    spatial_conv = Conv3D(filters=filters, kernel_size=(1, kernel_size[0], kernel_size[1]), padding=padding)(inputs)
    temporal_conv = Conv3D(filters=filters, kernel_size=(kernel_size[2], 1, 1), padding=padding)(spatial_conv)
    return temporal_conv

# %%
def ResidualMain(inputs, filters, kernel_size):
    conv2plus1d_1 = Conv2Plus1D(inputs, filters, kernel_size, padding='same')
    norm_1 = LayerNormalization()(conv2plus1d_1)
    relu_1 = ReLU()(norm_1)

    conv2plus1d_2 = Conv2Plus1D(relu_1, filters, kernel_size, padding='same')
    norm_2 = LayerNormalization()(conv2plus1d_2)

    return norm_2

# %%
from tensorflow.keras.layers import Dense, LayerNormalization

def Project(inputs, units):
    dense = Dense(units)(inputs)
    norm = LayerNormalization()(dense)
    return norm

# %%
def add_residual_block(input, filters, kernel_size):
  """
    Add residual blocks to the model. If the last dimensions of the input data
    and filter size does not match, project it such that last dimension matches.
  """
  out = ResidualMain(input,filters,
                     kernel_size)

  res = input
  # Using the Keras functional APIs, project the last dimension of the tensor to
  # match the new filter size
  if out.shape[-1] != input.shape[-1]:
    res = Project(res,out.shape[-1])

  return layers.add([res, out])

# %%
import einops
from tensorflow.keras import layers, Model

def ResizeVideo(video, height, width):
    # Assume the input 'video' has shape (batch_size, num_frames, original_height, original_width, channels)
    resized = layers.UpSampling3D(size=(1, height, width))(x)
    # Reshape the video tensor to work with Resizing layer
    reshaped_video = einops.rearrange(video, 'b t h w c -> (b t) h w c')

    # Create a Resizing layer
    resizing_layer = layers.Resizing(height, width)

    # Apply resizing to the images in the video
    resized_images = resizing_layer(reshaped_video)

    # Restore the original video shape
    resized_video = einops.rearrange(resized_images, '(b t) h w c -> b t h w c', t=video.shape[1])

    return resized_video

# %%
input_shape = (None, 10, HEIGHT, WIDTH, 3)

# Input layer
input_layer = layers.Input(shape=input_shape[1:])
x = input_layer

# Initial Conv2Plus1D layer
x = Conv2Plus1D(x,filters=16, kernel_size=(3, 7, 7), padding='same')
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = ResizeVideo(x, HEIGHT // 2, WIDTH // 2)

# Block 1
x = add_residual_block(x, 16, (3, 3, 3))
x = ResizeVideo(x, HEIGHT // 4, WIDTH // 4)

# Block 2
x = add_residual_block(x, 32, (3, 3, 3))
x = ResizeVideo(x, HEIGHT // 8, WIDTH // 8)

# Block 3
x = add_residual_block(x, 64, (3, 3, 3))
x = ResizeVideo(x, HEIGHT // 16, WIDTH // 16)

# Block 4
x = add_residual_block(x, 128, (3, 3, 3))

# Global Average Pooling and Dense layers
x = layers.GlobalAveragePooling3D()(x)
x = layers.Flatten()(x)
x = layers.Dense(10)(x)

# Create the model
model = Model(inputs=input_layer, outputs=x)

# %%
frames, label = next(iter(train_ds))
model.build(frames)

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001),
              metrics = ['accuracy'])

# %%
history = model.fit(x = train_ds,
                    epochs = 20,
                    validation_data = val_ds)
# Out:
# Epoch 1/20
#      14/Unknown - 298s 21s/step - loss: 2.6694 - accuracy: 0.0804
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-13b1ea463343> in <cell line: 1>()
# ----> 1 history = model.fit(x = train_ds,
#       2                     epochs = 20,
#       3                     validation_data = val_ds)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2494       (graph_function,
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496     return graph_function._call_flat(
#    2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1860         and executing_eagerly):
#    1861       # No tape is watching; skip to running the function.
# -> 1862       return self._build_call_outputs(self._inference_function.call(
#    1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
def plot_history(history):
  """
    Plotting training and validation learning curves.

    Args:
      history: model history with all the metric measures
  """
  fig, (ax1, ax2) = plt.subplots(2)

  fig.set_size_inches(18.5, 10.5)

  # Plot loss
  ax1.set_title('Loss')
  ax1.plot(history.history['loss'], label = 'train')
  ax1.plot(history.history['val_loss'], label = 'test')
  ax1.set_ylabel('Loss')

  # Determine upper bound of y-axis
  max_loss = max(history.history['loss'] + history.history['val_loss'])

  ax1.set_ylim([0, np.ceil(max_loss)])
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation'])

  # Plot accuracy
  ax2.set_title('Accuracy')
  ax2.plot(history.history['accuracy'],  label = 'train')
  ax2.plot(history.history['val_accuracy'], label = 'test')
  ax2.set_ylabel('Accuracy')
  ax2.set_ylim([0, 1])
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'])

  plt.show()

plot_history(history)

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 13/13 [==============================] - 15s 1s/step - loss: 5.7015 - accuracy: 0.1300
# {'loss': 5.701539516448975, 'accuracy': 0.12999999523162842}
